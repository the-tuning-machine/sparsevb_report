# %% [markdown]
# # SparsevB Experiments
#
# Run all experiments from the report. Each cell runs one script.

# %% [markdown]
# ## 1. Correlated groups (needle in a haystack)
#
# Toeplitz intra-group correlation, varying rho from 0 to 0.99.

# %%
# %run 1_correlated_groups.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Cours ENS/Bayesian Machine Learning/report/1_correlated_groups.py:13
#      11 from scipy.linalg import toeplitz, cholesky
#      12 from sparsevb import svb_fit_linear
# ---> 13 import matplotlib.pyplot as plt
#      14 from collections import defaultdict
#      17 def generate_correlated_groups(n, G, B, rho, active_per_group, signal_strength,
#      18                                seed=None):
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## 2. Non-Gaussian robustness
#
# Test 7 distributions (Gaussian, Student(1/2/3), Laplace, Cauchy, Uniform) for noise, design, and coefficients.

# %%
# %run 2_non_gaussian_robustness.py

# %% [markdown]
# ## 3. Sparsity limits
#
# Effect of increasing s/n ratio and scaling behavior.

# %%
# %run 3_sparsity_limits.py

# %% [markdown]
# ## 4. Signal strength
#
# Effect of decreasing signal-to-noise ratio and per-coefficient shrinkage.

# %%
# %run 4_signal_strength.py

# %% [markdown]
# ## 5. Compare selection methods
#
# SparsevB (gamma > 0.5) vs AIC, BIC, CV, Knockoffs, Stability Selection.

# %%
# %run 5_compare_methods.py

# %% [markdown]
# ## 6. Tune hyperparameters
#
# Grid search for Stability Selection hyperparameters (slow).

# %%
# %run 6_tune_hyperparams.py
